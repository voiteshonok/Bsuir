# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Вариант 3
# $y=|x|, a=-3, b=3$

# %% [markdown]
# <img src="images/assigment1.jpg" width="700">

# %% [markdown]
# ### 1. Формируем выборку
#
# $m_x=\frac{a+b}{2}=0, \sigma_x=\sqrt{\frac{(b-a)^2}{12}}=\sqrt{3}$

# %%
def get_x(a, b):
    return a + (b - a) * np.random.uniform()

def get_y(x):
    return np.abs(x)

# %%
L, R = -3, 3
a, b = -3, 3
N = 200
#N = int(input())
x = sorted([get_x(a, b) for i in range(N)])
y = get_y(x)
plt.plot(x, y)
plt.title("$\phi(x)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# ### 2. Вариационный ряд и эмпирическая функция распределения

# %%
unique, counts = np.unique(y, return_counts=True)
Y = dict(zip(unique, counts))
Y
# Out:
# {0.0038128410051490036: 1,
#  0.030051050567619697: 1,
#  0.03769662522830064: 1,
#  0.040525831360754605: 1,
#  0.05460955947939805: 1,
#  0.0769289591656177: 1,
#  0.12035212203762846: 1,
#  0.1375229530375517: 1,
#  0.16271281290962047: 1,
#  0.16405758791268577: 1,
#  0.17488930936291514: 1,
#  0.18343356030595448: 1,
#  0.2013963320555492: 1,
#  0.21072310223764035: 1,
#  0.22032399973451522: 1,
#  0.23233548998328857: 1,
#  0.24241513988548657: 1,
#  0.256176622674551: 1,
#  0.2742740860409345: 1,
#  0.28812123822205393: 1,
#  0.3200190937184364: 1,
#  0.33591263460161347: 1,
#  0.36726023942319586: 1,
#  0.38112828949065136: 1,
#  0.4164940421304699: 1,
#  0.4174413066289704: 1,
#  0.4651696464113453: 1,
#  0.4924397928841193: 1,
#  0.4965897519055611: 1,
#  0.503257766618272: 1,
#  0.5721557232223726: 1,
#  0.5875089557831963: 1,
#  0.5875311265151026: 1,
#  0.649636014681223: 1,
#  0.6577282692255091: 1,
#  0.6656489772050396: 1,
#  0.6685537859892614: 1,
#  0.6709091647089016: 1,
#  0.6786092651437348: 1,
#  0.679943222138903: 1,
#  0.6988268978084173: 1,
#  0.7055110653083441: 1,
#  0.7129024995607329: 1,
#  0.7352685497919258: 1,
#  0.7426902744966943: 1,
#  0.7482927370789794: 1,
#  0.7492219923146655: 1,
#  0.7637432390822463: 1,
#  0.7811099282537084: 1,
#  0.7844615506226909: 1,
#  0.7886087638725261: 1,
#  0.7951568288806294: 1,
#  0.8083294051876528: 1,
#  0.8146275330088573: 1,
#  0.8157041429315823: 1,
#  0.9041089569708167: 1,
#  0.9104338267170249: 1,
#  0.928308380712286: 1,
#  0.9325803195595612: 1,
#  0.9368194377440511: 1,
#  0.9379000406874756: 1,
#  0.9426582739089717: 1,
#  0.9454274862901402: 1,
#  0.973687590112565: 1,
#  0.9774672954233363: 1,
#  1.0057817942953706: 1,
#  1.01263026341684: 1,
#  1.0127476846914518: 1,
#  1.0486530019915208: 1,
#  1.050901787091806: 1,
#  1.0756370556969663: 1,
#  1.0781930344095387: 1,
#  1.0818634778063574: 1,
#  1.086319665445948: 1,
#  1.090760526334746: 1,
#  1.1138928124423821: 1,
#  1.1166815660111562: 1,
#  1.142596073747391: 1,
#  1.1443815552102823: 1,
#  1.1544268150189412: 1,
#  1.1664244919145432: 1,
#  1.1818490243000994: 1,
#  1.192841061674627: 1,
#  1.2032175101877467: 1,
#  1.2140911950940665: 1,
#  1.2327482576779571: 1,
#  1.23551750517752: 1,
#  1.240528977773883: 1,
#  1.2415744865867764: 1,
#  1.246618356900094: 1,
#  1.3324010200781808: 1,
#  1.3340788755258524: 1,
#  1.3433437100531895: 1,
#  1.3436746121827488: 1,
#  1.3541427235498817: 1,
#  1.3728187500636184: 1,
#  1.4040911193512882: 1,
#  1.4155781834387797: 1,
#  1.423816043701541: 1,
#  1.4272981682647847: 1,
#  1.428949137140415: 1,
#  1.4366689657632579: 1,
#  1.4452423110586734: 1,
#  1.4577800358392508: 1,
#  1.4708556386223706: 1,
#  1.4711024959425838: 1,
#  1.5195864717158023: 1,
#  1.534155814712184: 1,
#  1.5833980299477175: 1,
#  1.5917166731581833: 1,
#  1.6172270506898174: 1,
#  1.6278316394187566: 1,
#  1.6317790742151868: 1,
#  1.6387709105382102: 1,
#  1.6397659187890685: 1,
#  1.6469574215481426: 1,
#  1.6500952934494348: 1,
#  1.6914338065650734: 1,
#  1.7402086809786645: 1,
#  1.7460194583572228: 1,
#  1.7633219572771344: 1,
#  1.772582484672001: 1,
#  1.8041256254648834: 1,
#  1.8219317273381512: 1,
#  1.833429541882845: 1,
#  1.8657393070424666: 1,
#  1.8946867302092079: 1,
#  1.9160412792924868: 1,
#  1.9451915305168408: 1,
#  1.9491501679368886: 1,
#  1.956349646578392: 1,
#  1.962470123673195: 1,
#  1.968951881924089: 1,
#  1.9726969597644137: 1,
#  2.0247417417823836: 1,
#  2.044639662244087: 1,
#  2.044950140826513: 1,
#  2.064167828580313: 1,
#  2.0850875532037394: 1,
#  2.1321815684688685: 1,
#  2.142949842425129: 1,
#  2.156132456804963: 1,
#  2.1848985442542697: 1,
#  2.1906549968807414: 1,
#  2.1947871489170603: 1,
#  2.196794375348083: 1,
#  2.2288710480865266: 1,
#  2.2566395068036025: 1,
#  2.2573086116805285: 1,
#  2.264466926378585: 1,
#  2.266932736433796: 1,
#  2.296351821865838: 1,
#  2.3113211920941845: 1,
#  2.323447138226049: 1,
#  2.3491452908339197: 1,
#  2.3667173700779927: 1,
#  2.435518088013744: 1,
#  2.435593234819083: 1,
#  2.446373087695445: 1,
#  2.446563801768841: 1,
#  2.464944749720231: 1,
#  2.4719746485373033: 1,
#  2.5332560038845298: 1,
#  2.540108452654416: 1,
#  2.5554032448231183: 1,
#  2.5563117602431173: 1,
#  2.563553443696744: 1,
#  2.575212381574623: 1,
#  2.578230161552841: 1,
#  2.5901136869698553: 1,
#  2.6289488457845724: 1,
#  2.632746584652736: 1,
#  2.6657111111519356: 1,
#  2.6716682394305256: 1,
#  2.675160922252797: 1,
#  2.7082929128329685: 1,
#  2.714865413769621: 1,
#  2.721350592010147: 1,
#  2.7241415199887964: 1,
#  2.72833325594053: 1,
#  2.739084208758467: 1,
#  2.7548189216347145: 1,
#  2.760027331946138: 1,
#  2.7862475113967973: 1,
#  2.7875429507465963: 1,
#  2.797035992206455: 1,
#  2.8050702735115687: 1,
#  2.809228371085445: 1,
#  2.8132631864627022: 1,
#  2.8168286533176277: 1,
#  2.8291245581723077: 1,
#  2.880285160836098: 1,
#  2.898264261214446: 1,
#  2.9062968929285526: 1,
#  2.915664974482059: 1,
#  2.927887623755113: 1,
#  2.936480163067702: 1,
#  2.94781277284282: 1,
#  2.9506906126915755: 1,
#  2.9743003216325823: 1}

# %%
def F_y_emp(X, x0):
    count = 0
    for i in X:
        if i <= x0:
            count += 1
    return count / len(X)

# %%
f_y_emp = [F_y_emp(Y, y) for y in Y.keys()]
plt.plot(list(Y.keys()), f_y_emp)
plt.title("Empirical $F_y(y)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# ### 3. Теоритически находим функцию распределения

# %% [markdown]
# <img src="images/Lab1_3.jpg" width="450">

# %%
def F_x_ther(t):
    if t < -3:
        return 0
    elif t > 3:
        return 1
    else:
        return (t - L) / (R - L)  

plt.plot(x, [F_x_ther(x_0) for x_0 in x])
plt.title("Theoretical $F_x(x)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %%
def F_y_ther(y):
    if y < 0:
        return 0
    else:
        return F_x_ther(y) - F_x_ther(-y)

f_y_ther = [F_y_ther(y0) for y0 in list(Y.keys())]
plt.plot(list(Y.keys()), f_y_ther)
plt.title("Theoretical $F_y(y)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# ### Сравниваем теоритческую и эмпирическую

# %%
fig, ax = plt.subplots()

ax.plot(list(Y.keys()), f_y_ther, label="Theoretical")
ax.plot(list(Y.keys()), f_y_emp, label="Empirical")
ax.legend()
ax.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# # lab2
#
# <img src="images/assignment2.jpg" width="700">

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ### 1. Гистрограмма равноинтервальным методом, полигон расределения и эмпирическая функция распредеделения

# %%
X = list(Y.keys())

# %%
if N > 100:
    M = int(4 * np.log10(N))
else:
    M = int(np.sqrt(N))

# %%
h = (X[-1] - X[0]) / M
A_i = [X[0] + i * h for i in range(M+1)]

# %%
a = A_i[:-1]
b = A_i[1:]
intervals = list(zip(a, b))
print("intervals")
intervals
# Out:
# intervals
# [(0.0038128410051490036, 0.33386700551930826),
#  (0.33386700551930826, 0.6639211700334675),
#  (0.6639211700334675, 0.9939753345476268),
#  (0.9939753345476268, 1.324029499061786),
#  (1.324029499061786, 1.6540836635759453),
#  (1.6540836635759453, 1.9841378280901045),
#  (1.9841378280901045, 2.314191992604264),
#  (2.314191992604264, 2.644246157118423),
#  (2.644246157118423, 2.9743003216325823)]

# %%
m_i = np.zeros(len(intervals))
current_interval = 0
for value in X:
    if intervals[current_interval][0] < value and value < intervals[current_interval][1]:
        m_i[current_interval] += 1
        continue
    if intervals[current_interval][0] == value or value == intervals[current_interval][1]:
        m_i[current_interval] += 0.5
        continue
    current_interval += 1
m_i[0] += 0.5
m_i[-1] += 0.5
print("m_i")
m_i
# Out:
# m_i
# array([21., 13., 29., 24., 26., 16., 18., 18., 27.])

# %%
av_density = [round(value / len(X), 4) / h for value in m_i]
av_density
# Out:
# [0.3181296020141431,
#  0.19693737267542194,
#  0.4393218313528643,
#  0.36357668801616355,
#  0.3938747453508439,
#  0.24238445867744238,
#  0.2726825160121227,
#  0.2726825160121227,
#  0.409023774018184]

# %%
interval_x = [intervals[0][0]]
interval_y = [0]
for i in range(len(intervals)):
    interval_x.append(intervals[i][0])
    interval_y.append(av_density[i])
    interval_x.append(intervals[i][1])
    interval_y.append(av_density[i])
interval_x.append(intervals[-1][1])
interval_y.append(0)

# %%
plt.plot(interval_x, interval_y)
plt.title("Гистограмма равноинтервальным методом")
plt.xlabel("y")
plt.ylabel("$f*(y)$")
plt.show()

# %% [markdown]
# # Lab3

# %% [markdown]
# <img src="images/assigment3.jpg" width="700">

# %% [markdown]
# ## 1. Критерий Пирсона

# %%
intervals
# Out:
# [(0.0038128410051490036, 0.33386700551930826),
#  (0.33386700551930826, 0.6639211700334675),
#  (0.6639211700334675, 0.9939753345476268),
#  (0.9939753345476268, 1.324029499061786),
#  (1.324029499061786, 1.6540836635759453),
#  (1.6540836635759453, 1.9841378280901045),
#  (1.9841378280901045, 2.314191992604264),
#  (2.314191992604264, 2.644246157118423),
#  (2.644246157118423, 2.9743003216325823)]

# %%
av_density
# Out:
# [0.3181296020141431,
#  0.19693737267542194,
#  0.4393218313528643,
#  0.36357668801616355,
#  0.3938747453508439,
#  0.24238445867744238,
#  0.2726825160121227,
#  0.2726825160121227,
#  0.409023774018184]

# %% [markdown]
# Перейдем к простому вариационному ряду, выбрав в качестве вариант середины
# интервалов

# %%
x_i = [(i[0]+i[1])/2 for i in intervals]
pd.DataFrame(
    {
        'x_i': x_i,
        'n_i': list(map(int, m_i))
    }
)
# Out:
#         x_i  n_i
# 0  0.168840   21
# 1  0.498894   13
# 2  0.828948   29
# 3  1.159002   24
# 4  1.489057   26
# 5  1.819111   16
# 6  2.149165   18
# 7  2.479219   18
# 8  2.809273   27

# %%
average = sum(x_i*m_i) / N
print("Выборочное среднее ", average)
# Out:
# Выборочное среднее  1.4443467554692484

# %%
x_i = np.array(x_i)

# %%
variance = sum((x_i - average)**2 * m_i) / N
print("Выборочная дисперсия ", variance)
# Out:
# Выборочная дисперсия  0.6977125254621419

# %%
a_, b_ = average - np.sqrt(3*variance), average + np.sqrt(3*variance)

# %%
type(F_x_ther)
# Out:
# function

# %%
F_x_ther(1)
# Out:
# 0.6666666666666666

# %%
n_i_ = np.array([N*(F_y_ther(i[1])-F_y_ther(i[0])) for i in intervals])
print("Теоритические частоты ", n_i_)
# Out:
# Теоритические частоты  [22.00361097 22.00361097 22.00361097 22.00361097 22.00361097 22.00361097
#  22.00361097 22.00361097 22.00361097]

# %%
print("{\chi}^2 = ", sum((n_i_ - m_i)**2 / n_i_))
# Out:
# {\chi}^2 =  11.091063613256212

# %%
print(f"число степеней свободы k = s - 1 = {len(intervals) - 1}")
# Out:
# число степеней свободы k = s - 1 = 8

# %%
print(f"при alpha = 0.05 chi^2={15.5}, то есть гипотеза о равномерном распределении принимается")
# Out:
# при alpha = 0.05 chi^2=15.5, то есть гипотеза о равномерном распределении принимается
