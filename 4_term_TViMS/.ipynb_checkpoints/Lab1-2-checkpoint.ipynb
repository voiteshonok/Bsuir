# %%
import numpy as np
import math
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Вариант 3
# $y=|x|, a=-3, b=3$

# %% [markdown]
# <img src="images/assigment1.jpg" width="700">

# %% [markdown]
# ### 1. Формируем выборку
#
# $m_x=\frac{a+b}{2}=0, \sigma_x=\sqrt{\frac{(b-a)^2}{12}}=\sqrt{3}$

# %%
def get_x(a, b):
    return a + (b - a) * np.random.uniform()

def get_y(x):
    return np.abs(x)

# %%
L, R = -3, 3
a, b = -3, 3
N = 1000
#N = int(input())
x = sorted([get_x(a, b) for i in range(N)])
y = get_y(x)
plt.plot(x, y)
plt.title("$\phi(x)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# ### 2. Вариационный ряд и эмпирическая функция распределения

# %%
unique, counts = np.unique(y, return_counts=True)
Y = dict(zip(unique, counts))
Y
# Out:
# {0.0027004935506900196: 1,
#  0.009367659073233003: 1,
#  0.01045647379334591: 1,
#  0.011625383816777024: 1,
#  0.01808209266963079: 1,
#  0.02103832983057652: 1,
#  0.021533561348419106: 1,
#  0.028260770328040863: 1,
#  0.03231699100013996: 1,
#  0.033912559059448455: 1,
#  0.036263712082865496: 1,
#  0.0379352216835529: 1,
#  0.03820297817235918: 1,
#  0.03963950645148451: 1,
#  0.04128837689109588: 1,
#  0.042045997412124336: 1,
#  0.04281716026357163: 1,
#  0.04561223227355571: 1,
#  0.051581967889092084: 1,
#  0.05692197481639161: 1,
#  0.060267816503557725: 1,
#  0.06071206951280139: 1,
#  0.06225061284987099: 1,
#  0.0656917466517486: 1,
#  0.0687201470468013: 1,
#  0.06993022761214451: 1,
#  0.07109917730621707: 1,
#  0.07807815719589994: 1,
#  0.07889170866463235: 1,
#  0.0795067620258827: 1,
#  0.08108281881570578: 1,
#  0.08492410990454857: 1,
#  0.09138366037651968: 1,
#  0.0950783100210888: 1,
#  0.09531687742229433: 1,
#  0.09604504621543519: 1,
#  0.09964570963887187: 1,
#  0.1000749135306922: 1,
#  0.10139800568800172: 1,
#  0.11325649882212385: 1,
#  0.11332575939349976: 1,
#  0.11374033890633672: 1,
#  0.1143977271625225: 1,
#  0.11982137366135293: 1,
#  0.1261138408452238: 1,
#  0.1319973015778091: 1,
#  0.13243916466465855: 1,
#  0.13318650073749705: 1,
#  0.1338179980972649: 1,
#  0.13388403772000768: 1,
#  0.1358923232939495: 1,
#  0.1394950719513588: 1,
#  0.1395322746230141: 1,
#  0.14601390402111214: 1,
#  0.1496537606319599: 1,
#  0.15858406647949508: 1,
#  0.16004719005767853: 1,
#  0.1623693171039089: 1,
#  0.16812527386390652: 1,
#  0.1716289962146118: 1,
#  0.17190950005119943: 1,
#  0.17638068987564548: 1,
#  0.17881305086882104: 1,
#  0.18006641796440803: 1,
#  0.18393707541535154: 1,
#  0.18471354063851742: 1,
#  0.18482544343899265: 1,
#  0.1860911800687881: 1,
#  0.18704787117957622: 1,
#  0.18729739704035486: 1,
#  0.1941580683945987: 1,
#  0.19611913740827447: 1,
#  0.19807356928748288: 1,
#  1.3765176866098434: 1,
#  1.376937828198737: 1,
#  1.3770913569402534: 1,
#  1.3783626376008256: 1,
#  1.3803496860457716: 1,
#  1.3872329779917711: 1,
#  1.3984566607335756: 1,
#  1.4023926631450356: 1,
#  1.4035880981873392: 1,
#  1.4069325198859137: 1,
#  1.4118845920923: 1,
#  1.4151576393390044: 1,
#  1.4194021190595634: 1,
#  1.4252489773005061: 1,
#  1.4291489386448704: 1,
#  1.4293596924602305: 1,
#  1.4296589220796: 1,
#  1.4321458737872523: 1,
#  1.4335345108002135: 1,
#  1.4361634576649898: 1,
#  1.4366664947952854: 1,
#  1.4384395872499323: 1,
#  1.4390900326326725: 1,
#  1.4393159561868663: 1,
#  1.4410379783947054: 1,
#  1.4413835027186055: 1,
#  1.4414826856902585: 1,
#  1.4421718375660022: 1,
#  1.4483725682650732: 1,
#  1.4503440638730012: 1,
#  1.4523871327109363: 1,
#  1.455443409481511: 1,
#  1.4627650364584213: 1,
#  1.4784953218895467: 1,
#  1.4787142168864837: 1,
#  1.480895308886204: 1,
#  1.48803909988791: 1,
#  1.4911771920310208: 1,
#  1.4950093692865272: 1,
#  1.4958519406941866: 1,
#  1.4968232439182125: 1,
#  1.5022225396093254: 1,
#  1.5074072803987528: 1,
#  1.5116410534958895: 1,
#  1.5172058763873544: 1,
#  1.5185703870678682: 1,
#  1.52025025215001: 1,
#  1.5202908118487644: 1,
#  1.5208794949222648: 1,
#  1.5220800165453539: 1,
#  1.5252286384963174: 1,
#  1.5308176693194815: 1,
#  1.5357772606544688: 1,
#  1.540295380607823: 1,
#  1.547454266296227: 1,
#  1.5488279270818985: 1,
#  1.5521296600084622: 1,
#  1.5533818863888458: 1,
#  1.559176113730948: 1,
#  1.5632560156561652: 1,
#  1.5690886067362833: 1,
#  1.569365460524422: 1,
#  1.572705863547153: 1,
#  1.5729786773852015: 1,
#  1.575164588107454: 1,
#  1.5820777795054313: 1,
#  1.5861319258344402: 1,
#  1.586289013944615: 1,
#  1.588823833766442: 1,
#  1.5892008892841039: 1,
#  1.589445550951421: 1,
#  1.5904174293010698: 1,
#  1.6008986230238333: 1,
#  1.6012495742146429: 1,
#  1.6013571289056143: 1,
#  1.6039527795623414: 1,
#  1.6045904939545277: 1,
#  1.605608274643472: 1,
#  1.6089833696078306: 1,
#  1.6107895113805728: 1,
#  1.6120901289522824: 1,
#  1.6167776875687612: 1,
#  1.6180481279244: 1,
#  1.622652435257753: 1,
#  1.6232375206682743: 1,
#  1.6252316643713218: 1,
#  1.6315704233726056: 1,
#  1.6325782103552688: 1,
#  1.6363932157446444: 1,
#  1.6377574601674798: 1,
#  1.6386215815550482: 1,
#  1.6424749041436701: 1,
#  1.6433282135217295: 1,
#  1.644136417270289: 1,
#  1.649011642996416: 1,
#  1.6552937315026064: 1,
#  1.6559363110946166: 1,
#  1.663808685812396: 1,
#  1.6643838510073632: 1,
#  1.6667359566572184: 1,
#  1.6673144290617001: 1,
#  2.6313678271377494: 1,
#  2.6334806367011083: 1,
#  2.6337330170029682: 1,
#  2.6395888208533638: 1,
#  2.647560442614221: 1,
#  2.6486371590202253: 1,
#  2.649201236724446: 1,
#  2.6500361342170535: 1,
#  2.6517224232793177: 1,
#  2.652624653986561: 1,
#  2.6540874441250706: 1,
#  2.6555416687771842: 1,
#  2.660931993261083: 1,
#  2.6631754497031945: 1,
#  2.6637567232220585: 1,
#  2.665344668881465: 1,
#  2.66595810122395: 1,
#  2.6663052325957457: 1,
#  2.668386618938966: 1,
#  2.6698486924408193: 1,
#  2.676719855653946: 1,
#  2.681702526789854: 1,
#  2.6830847495160706: 1,
#  2.6846117213354583: 1,
#  2.685523884176197: 1,
#  2.689319592578986: 1,
#  2.691104458851024: 1,
#  2.69203129365682: 1,
#  2.7013010992805873: 1,
#  2.702322116436931: 1,
#  2.709861857658569: 1,
#  2.7148445952794935: 1,
#  2.7214956478647414: 1,
#  2.728893140842819: 1,
#  2.7317728161190287: 1,
#  2.7336680715245265: 1,
#  2.741254646999118: 1,
#  2.744878371500535: 1,
#  2.748449947202416: 1,
#  2.749149239730171: 1,
#  2.749378452788296: 1,
#  2.7500561042138107: 1,
#  2.750706675627419: 1,
#  2.7515397340402075: 1,
#  2.7525287525989137: 1,
#  2.755508251081643: 1,
#  2.756026413112859: 1,
#  2.7625911075955596: 1,
#  2.7630120586815217: 1,
#  2.7651724200286507: 1,
#  2.7750880928432338: 1,
#  2.7751366912885107: 1,
#  2.7785962984187136: 1,
#  2.779719505025416: 1,
#  2.790336790996437: 1,
#  2.7917465093961393: 1,
#  2.7956389980127643: 1,
#  2.801003700924479: 1,
#  2.803807612011904: 1,
#  2.814562094143276: 1,
#  2.815046511082671: 1,
#  2.817097004514017: 1,
#  2.8173521209320747: 1,
#  2.822285429671247: 1,
#  2.829885625049344: 1,
#  2.836659867919293: 1,
#  2.838436219480867: 1,
#  2.840236486955039: 1,
#  2.844347020488649: 1,
#  2.845932748286824: 1,
#  2.847442589885171: 1,
#  2.848857467156406: 1,
#  2.8496748240531007: 1,
#  2.85433537087711: 1,
#  2.8549534531360927: 1,
#  2.863731197377966: 1,
#  2.863771045811944: 1,
#  2.864076203092929: 1,
#  2.8643413947592267: 1,
#  2.86808932902031: 1,
#  2.8685338001920924: 1,
#  2.8697992831335997: 1,
#  2.8705174375216442: 1,
#  2.87398160737746: 1,
#  2.8767784906546994: 1,
#  2.884999172626699: 1,
#  2.8963373676823414: 1,
#  2.8975700439162386: 1,
#  2.8976310426997003: 1,
#  2.89778200632343: 1,
#  2.9002203507881803: 1,
#  2.9053765984283135: 1,
#  2.912735834660875: 1,
#  2.916013924778656: 1,
#  2.91650052076091: 1,
#  2.9167441482510847: 1,
#  2.9211750077837335: 1,
#  2.93227489797336: 1,
#  2.9336099870947523: 1,
#  2.9398170306358735: 1,
#  2.942977495817998: 1,
#  2.9448954775678327: 1,
#  2.949089516946983: 1,
#  2.9537341813145996: 1,
#  2.9546984508076584: 1,
#  2.9626594695958754: 1,
#  2.9637400875517645: 1,
#  2.9693000950088937: 1,
#  2.970176714104398: 1,
#  2.9737620624265366: 1,
#  2.9749039376346653: 1,
#  2.9780685532753477: 1,
#  2.9782985368699775: 1,
#  2.9841871456338547: 1,
#  2.990271836354278: 1,
#  2.991094466665804: 1,
#  2.992027662071087: 1,
#  2.9973415809604997: 1,
#  2.998843247741502: 1}

# %%
def F_y_emp(X, x0):
    count = 0
    for i in X:
        if i <= x0:
            count += 1
    return count / len(X)

# %%
f_y_emp = [F_y_emp(Y, y) for y in Y.keys()]

interval_x = [2*a, list(Y.keys())[0]]
interval_y = [0, 0]
for i in range(len(list(Y.keys()))-1):
    interval_x.append(list(Y.keys())[i])
    interval_y.append(f_y_emp[i])
    interval_x.append(list(Y.keys())[i+1])
    interval_y.append(f_y_emp[i])
interval_x.append(list(Y.keys())[-1])
interval_y.append(1)
interval_x.append(2*b)
interval_y.append(1)
    
plt.plot(interval_x, interval_y)
plt.title("Empirical $F_y(y)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# ### 3. Теоритически находим функцию распределения

# %% [markdown]
# <img src="images/Lab1_3.jpg" width="450">

# %%
def F_x_ther(t):
    if t < -3:
        return 0
    elif t > 3:
        return 1
    else:
        return (t - a) / (b - a)  

plt.plot(x, [F_x_ther(x_0) for x_0 in x])
plt.title("Theoretical $F_x(x)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %%
def F_y_ther(y):
    if y < 0:
        return 0
    else:
        return F_x_ther(y) - F_x_ther(-y)

f_y_ther = [F_y_ther(y0) for y0 in list(Y.keys())]
plt.plot(list(Y.keys()), f_y_ther)
plt.title("Theoretical $F_y(y)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# ### Сравниваем теоритческую и эмпирическую

# %%
fig, ax = plt.subplots()

ax.plot(list(Y.keys()), f_y_ther, label="Theoretical")
ax.plot(interval_x, interval_y, label="Empirical")
ax.legend()
ax.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# # lab2
#
# <img src="images/assignment2.jpg" width="700">

# %% [markdown]
# ## Задание 2

# %% [markdown]
# ### 1. Гистрограмма равноинтервальным методом, полигон расределения и эмпирическая функция распредеделения

# %%
X = list(Y.keys())

# %%
if N > 100:
    M = int(4 * np.log10(N))
else:
    M = int(np.sqrt(N))

# %%
h = (X[-1] - X[0]) / M
A_i = [X[0] + i * h for i in range(M+1)]

# %%
a = A_i[:-1]
b = A_i[1:]
intervals = list(zip(a, b))
print("intervals")
intervals
# Out:
# intervals
# [(0.0027004935506900196, 0.2523790563999243),
#  (0.2523790563999243, 0.5020576192491586),
#  (0.5020576192491586, 0.751736182098393),
#  (0.751736182098393, 1.0014147449476272),
#  (1.0014147449476272, 1.2510933077968616),
#  (1.2510933077968616, 1.500771870646096),
#  (1.500771870646096, 1.7504504334953301),
#  (1.7504504334953301, 2.0001289963445643),
#  (2.0001289963445643, 2.249807559193799),
#  (2.249807559193799, 2.499486122043033),
#  (2.499486122043033, 2.7491646848922673),
#  (2.7491646848922673, 2.998843247741502)]

# %%
m_i = np.zeros(len(intervals))
current_interval = 0
for value in X:
    if intervals[current_interval][0] < value and value < intervals[current_interval][1]:
        m_i[current_interval] += 1
        continue
    if intervals[current_interval][0] == value or value == intervals[current_interval][1]:
        m_i[current_interval] += 0.5
        continue
    current_interval += 1
m_i[0] += 0.5
m_i[-1] += 0.5
print("m_i")
m_i
# Out:
# m_i
# array([93., 76., 93., 75., 86., 88., 85., 78., 67., 84., 86., 78.])

# %%
av_density = [round(value / len(X), 4) / h for value in m_i]
av_density
# Out:
# [0.3724789142436591,
#  0.3043913707797644,
#  0.3724789142436591,
#  0.3003862211642412,
#  0.3444428669349966,
#  0.352453166166043,
#  0.3404377173194734,
#  0.3124016700108109,
#  0.2683450242400555,
#  0.3364325677039502,
#  0.3444428669349966,
#  0.3124016700108109]

# %%
interval_x = [intervals[0][0]]
interval_y = [0]
for i in range(len(intervals)):
    interval_x.append(intervals[i][0])
    interval_y.append(av_density[i])
    interval_x.append(intervals[i][1])
    interval_y.append(av_density[i])
interval_x.append(intervals[-1][1])
interval_y.append(0)

# %%
plt.plot(interval_x, interval_y)
plt.title("Гистограмма равноинтервальным методом")
plt.xlabel("y")
plt.ylabel("$f*(y)$")
plt.show()

# %%
polygon_x = [(intervals[i][0] + intervals[i][1]) / 2 for i in range(len(intervals))]

plt.plot(interval_x, interval_y)
plt.plot(polygon_x, av_density)
plt.title("Полигон и равноинтервальная гистограмма")
plt.show()

# %%
empiric_func = []
sum = 0
for i in m_i:
    empiric_func.append(round(sum / N, 5))
    sum += i
empiric_func.append(1)
print(f'empirical function: {empiric_func}')
# Out:
# empirical function: [0.0, 0.093, 0.169, 0.262, 0.337, 0.423, 0.511, 0.596, 0.674, 0.741, 0.825, 0.911, 1]

# %%
interval_x_F = [intervals[0][0]]
interval_y_F = [0]
for i in range(len(intervals)):
    interval_x_F.append(intervals[i][0])
    interval_y_F.append(empiric_func[i+1])
    interval_x_F.append(intervals[i][1])
    interval_y_F.append(empiric_func[i+1])

fig, ax = plt.subplots()

ax.plot(list(Y.keys()), f_y_ther, label="Theoretical")
ax.plot(interval_x_F, interval_y_F, label="Empirical")
ax.legend()
ax.grid(True, which='both', linestyle='--')
plt.show()

# %%
pd.DataFrame(
    {
        'interval': intervals,
        'm_i': m_i,
        'h_i': h,
        'density': av_density
    }
)
# Out:
#                                        interval   m_i       h_i   density
# 0   (0.0027004935506900196, 0.2523790563999243)  93.0  0.249679  0.372479
# 1      (0.2523790563999243, 0.5020576192491586)  76.0  0.249679  0.304391
# 2       (0.5020576192491586, 0.751736182098393)  93.0  0.249679  0.372479
# 3       (0.751736182098393, 1.0014147449476272)  75.0  0.249679  0.300386
# 4      (1.0014147449476272, 1.2510933077968616)  86.0  0.249679  0.344443
# 5       (1.2510933077968616, 1.500771870646096)  88.0  0.249679  0.352453
# 6       (1.500771870646096, 1.7504504334953301)  85.0  0.249679  0.340438
# 7      (1.7504504334953301, 2.0001289963445643)  78.0  0.249679  0.312402
# 8       (2.0001289963445643, 2.249807559193799)  67.0  0.249679  0.268345
# 9        (2.249807559193799, 2.499486122043033)  84.0  0.249679  0.336433
# 10      (2.499486122043033, 2.7491646848922673)  86.0  0.249679  0.344443
# 11      (2.7491646848922673, 2.998843247741502)  78.0  0.249679  0.312402

# %% [markdown]
# ### 2. Теоритическая плотность распределения

# %% [markdown]
# <img src="images/Lab2_2.jpg" width="500">

# %%
def F_x_ther(t):
    if abs(t) > 3:
        return 0
    else:
        return 1 / (R - L)  

plt.plot(x, [F_x_ther(x_0) for x_0 in x])
plt.title("Theoretical $f_x(x)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %%
def F_y_ther(y):
    if y < 0:
        return 0
    else:
        return F_x_ther(y) + F_x_ther(-y)

f_y_theoretical = [F_y_ther(y0) for y0 in list(Y.keys())]
plt.plot(list(Y.keys()), f_y_theoretical)
plt.title("Theoretical $f_y(y)$")
plt.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# ### Сравниваем теоритческую и эмпирическую

# %%
fig, ax = plt.subplots()

ax.plot(list(Y.keys()), f_y_theoretical, label="Theoretical")
ax.plot(interval_x, interval_y, label="Empirical")
ax.legend()
ax.grid(True, which='both', linestyle='--')
plt.show()

# %% [markdown]
# ## Задание 3

# %% [markdown]
# ### 1. Гистрограмма равновероятностным методом, полигон расределения и эмпирическая функция распредеделения

# %%
m = N // M

# %%
A = np.zeros(M)
B = np.zeros(M)
A[0] = X[0]
for i in range(1, M):
    B[i-1] = A[i] = (X[i*m] + X[i*m + 1]) / 2
B[-1] = X[-1]

# %%
intervals = list(zip(A, B))
intervals
# Out:
# [(0.0027004935506900196, 0.23140530755718358),
#  (0.23140530755718358, 0.49096023316166826),
#  (0.49096023316166826, 0.7196035833611503),
#  (0.7196035833611503, 0.9759620313856443),
#  (0.9759620313856443, 1.2342764986849204),
#  (1.2342764986849204, 1.4401769672907858),
#  (1.4401769672907858, 1.6850996888603733),
#  (1.6850996888603733, 1.9424582531057624),
#  (1.9424582531057624, 2.2338415570669086),
#  (2.2338415570669086, 2.4899138904028986),
#  (2.4899138904028986, 2.72519439435378),
#  (2.72519439435378, 2.998843247741502)]

# %%
h_i = [interval[1] - interval[0] for interval in intervals]
h_i
# Out:
# [0.22870481400649356,
#  0.2595549256044847,
#  0.228643350199482,
#  0.25635844802449403,
#  0.2583144672992761,
#  0.20590046860586542,
#  0.2449227215695875,
#  0.25735856424538905,
#  0.2913833039611462,
#  0.25607233333599,
#  0.2352805039508814,
#  0.27364885338772194]

# %%
f_i = [m/h_i[i]/N for i in range(M)]
f_i
# Out:
# [0.3629132178986114,
#  0.31977817337389763,
#  0.3630107760736793,
#  0.32376541767825684,
#  0.3213137880652982,
#  0.40310738757413206,
#  0.33888240122473906,
#  0.32250723904746476,
#  0.2848481669048115,
#  0.3241271671902818,
#  0.35277041066406245,
#  0.30330841504532335]

# %%
interval_x = [intervals[0][0]]
interval_y = [0]
for i in range(len(intervals)):
    interval_x.append(intervals[i][0])
    interval_y.append(f_i[i])
    interval_x.append(intervals[i][1])
    interval_y.append(f_i[i])
interval_x.append(intervals[-1][1])
interval_y.append(0)

# %%
plt.plot(interval_x, interval_y)
plt.title("Гистограмма равновероятностным методом")
plt.xlabel("y")
plt.ylabel("$f*(y)$")
plt.show()

# %%
polygon_x = [(intervals[i][0] + intervals[i][1]) / 2 for i in range(len(intervals))]

plt.plot(interval_x, interval_y)
plt.plot(polygon_x, f_i)
plt.title("Полигон и равновероятностная гистограмма")
plt.show()

# %%
empiric_func = []
sum = 0
for i in f_i:
    empiric_func.append(round(sum/max(X), 5))
    sum += i
empiric_func.append(1)
print(f'empirical function: {empiric_func}')
# Out:
# empirical function: [0.0, 0.12102, 0.22765, 0.3487, 0.45667, 0.56381, 0.69823, 0.81124, 0.91878, 1.01377, 1.12185, 1.23949, 1]

# %%
interval_x_F = [intervals[0][0]]
interval_y_F = [0]
for i in range(len(intervals)):
    interval_x_F.append(intervals[i][0])
    interval_y_F.append(empiric_func[i+1])
    interval_x_F.append(intervals[i][1])
    interval_y_F.append(empiric_func[i+1])

fig, ax = plt.subplots()

ax.plot(list(Y.keys()), f_y_ther, label="Theoretical")
ax.plot(interval_x_F, interval_y_F, label="Empirical")
ax.legend()
ax.grid(True, which='both', linestyle='--')
plt.show()

# %%
pd.DataFrame(
    {
        'interval': intervals,
        'm_i': m,
        'h_i': h_i,
        'f_i': f_i
    }
)
# Out:
#                                         interval  m_i       h_i       f_i
# 0   (0.0027004935506900196, 0.23140530755718358)   83  0.228705  0.362913
# 1     (0.23140530755718358, 0.49096023316166826)   83  0.259555  0.319778
# 2      (0.49096023316166826, 0.7196035833611503)   83  0.228643  0.363011
# 3       (0.7196035833611503, 0.9759620313856443)   83  0.256358  0.323765
# 4       (0.9759620313856443, 1.2342764986849204)   83  0.258314  0.321314
# 5       (1.2342764986849204, 1.4401769672907858)   83  0.205900  0.403107
# 6       (1.4401769672907858, 1.6850996888603733)   83  0.244923  0.338882
# 7       (1.6850996888603733, 1.9424582531057624)   83  0.257359  0.322507
# 8       (1.9424582531057624, 2.2338415570669086)   83  0.291383  0.284848
# 9       (2.2338415570669086, 2.4899138904028986)   83  0.256072  0.324127
# 10        (2.4899138904028986, 2.72519439435378)   83  0.235281  0.352770
# 11         (2.72519439435378, 2.998843247741502)   83  0.273649  0.303308

# %% [markdown]
# ### 2. Сравнить полученные результаты

# %%
fig, ax = plt.subplots()

ax.plot(list(Y.keys()), f_y_theoretical, label="Theoretical")
ax.plot(interval_x, interval_y, label="Empirical")
ax.legend()
ax.grid(True, which='both', linestyle='--')
plt.show()
